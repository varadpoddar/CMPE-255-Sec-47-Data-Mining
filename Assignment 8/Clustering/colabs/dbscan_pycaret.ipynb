# %% [markdown]
# # DBSCAN Clustering with PyCaret
# PyCaret clustering module; demonstrates DBSCAN on a toy dataset.

# %%
# Install
# !pip install -q pycaret[analysis] pandas seaborn
# Out:
# zsh:1: no matches found: pycaret[analysis]

# %%
import pandas as pd, seaborn as sns, matplotlib.pyplot as plt
from sklearn.datasets import make_moons
from pycaret.clustering import setup, create_model, assign_model, plot_model
X, _ = make_moons(n_samples=300, noise=0.05, random_state=42)
df = pd.DataFrame(X, columns=['x1','x2'])
sns.scatterplot(x='x1', y='x2', data=df, s=10)
plt.title('Two moons dataset')
plt.show()

# %%
clf1 = setup(data=df, session_id=42, normalize=False, verbose=False)
db = create_model('dbscan')
assigned = assign_model(db)
assigned.head()
# Out:
# <style type="text/css">
# </style>
# <table id="T_8dc8d">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_8dc8d_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_8dc8d_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_8dc8d_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_8dc8d_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_8dc8d_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_8dc8d_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8dc8d_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_8dc8d_row0_col0" class="data row0 col0" >0</td>
#       <td id="T_8dc8d_row0_col1" class="data row0 col1" >0</td>
#       <td id="T_8dc8d_row0_col2" class="data row0 col2" >0</td>
#       <td id="T_8dc8d_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_8dc8d_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_8dc8d_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
#          x1        x2    Cluster
# 0  0.622519 -0.372101  Cluster 0
# 1  1.904269 -0.136303  Cluster 0
# 2 -0.069431  0.456117  Cluster 0
# 3  0.933899  0.237483  Cluster 0
# 4  1.180359 -0.490847  Cluster 0

# %%
plot_model(db, plot='cluster')

# %% [markdown]
# ## Notes
# - Tune eps/min_samples in PyCaret by passing hyperparameters.
# - Use other plots: tsne, umap.
